# %% [markdown]
# # 01 — Data Exploration
#
# This notebook explores the training dataset for CrashSight AI.
#
# **Contents:**
# - Load and visualise sample satellite tiles per crash class
# - Check annotation quality and bounding box distribution
# - Analyse class balance and dataset statistics
# - Visualise hard negatives vs positives
#
# > Run this after collecting initial training data via `src.dataset.downloader`.

# %%
# TODO: Implement data exploration
