# %% [markdown]
# # 02 — Model Training
#
# This notebook walks through training the CrashSight AI detection model.
#
# **Contents:**
# - Load and configure YOLOv8 with COCO pretrained weights
# - Fine-tune on crash site dataset
# - Evaluate mAP, recall, and FPR per class
# - Export trained model weights
#
# > Requires training data in `data/processed/`.

# %%
# TODO: Implement model training walkthrough
