# %% [markdown]
# # 04 — Cross-Reference Demo
#
# Demonstrates the news cross-referencing engine.
#
# **Contents:**
# - Take a sample detection with known coordinates
# - Query NewsAPI and GDELT for matching articles
# - Score matches using the weighted algorithm
# - Assign a category label
#
# > Requires a NewsAPI key in `.env`.

# %%
# TODO: Implement cross-reference demo
