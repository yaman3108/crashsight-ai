# %% [markdown]
# # 03 — Scan Pipeline Demo
#
# Demonstrates running the scan pipeline on a small region.
#
# **Contents:**
# - Define a scan zone (e.g., a section of Mediterranean coastline)
# - Generate tile grid
# - Run inference and collect detections
# - Visualise results on a map

# %%
# TODO: Implement scan pipeline demo
